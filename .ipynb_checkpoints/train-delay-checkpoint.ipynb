# %%
import pandas as pd

df = pd.read_csv("data/train_delays.csv")  # adjust filename if different
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nSample:")
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("data/train_delays.csv")  # adjust filename if different
#       4 print("Shape:", df.shape)
#
# ModuleNotFoundError: No module named 'pandas'
